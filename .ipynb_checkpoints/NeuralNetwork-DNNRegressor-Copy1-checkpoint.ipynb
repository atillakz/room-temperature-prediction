# %%
import tensorflow as tf

# %%
#Now to predict values we do the following
pred_input_func=tf.estimator.inputs.pandas_input_fn(x=X_eval,y=y_eval,batch_size=10,num_epochs=1,shuffle=False)
preds=model.predict(input_fn=pred_input_func)

predictions=list(preds)
final_pred=[]
for pred in predictions:
    final_pred.append(pred["predictions"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6ba2c2c618d4> in <module>
#       1 #Now to predict values we do the following
# ----> 2 pred_input_func=tf.estimator.inputs.pandas_input_fn(x=X_eval,y=y_eval,batch_size=10,num_epochs=1,shuffle=False)
#       3 preds=model.predict(input_fn=pred_input_func)
#       4
#       5 predictions=list(preds)
#
# NameError: name 'X_eval' is not defined

# %%
final_pred
# Out:
# [array([22.754854], dtype=float32),
#  array([22.32163], dtype=float32),
#  array([21.819963], dtype=float32),
#  array([25.189617], dtype=float32),
#  array([22.308739], dtype=float32),
#  array([25.441347], dtype=float32),
#  array([22.784212], dtype=float32),
#  array([22.084219], dtype=float32),
#  array([22.344631], dtype=float32),
#  array([23.835928], dtype=float32),
#  array([23.913324], dtype=float32),
#  array([21.441858], dtype=float32),
#  array([21.69895], dtype=float32),
#  array([27.871807], dtype=float32),
#  array([22.308739], dtype=float32),
#  array([25.56609], dtype=float32),
#  array([22.34463], dtype=float32),
#  array([21.104515], dtype=float32)]

# %%
y_eval
# Out:
# time
# 2019-06-11 21:31:25.175441    24.0
# 2019-06-13 02:47:28.215838    23.0
# 2019-06-12 04:31:52.367171    22.0
# 2019-06-12 22:07:10.215474    26.0
# 2019-06-13 00:27:19.836807    23.0
# 2019-06-11 18:11:12.294045    25.0
# 2019-06-11 23:11:32.282806    23.0
# 2019-06-12 02:11:44.077216    23.0
# 2019-06-12 00:51:38.272132    22.0
# 2019-06-11 16:31:06.414038    24.0
# 2019-06-13 09:07:53.239722    23.0
# 2019-06-12 00:31:37.056886    21.0
# 2019-06-11 23:31:33.444426    23.0
# 2019-06-11 16:51:07.581839    24.0
# 2019-06-12 01:11:39.496852    22.0
# 2019-06-11 20:31:21.702405    24.0
# 2019-06-13 03:27:30.676440    22.0
# 2019-06-13 05:27:38.822871    22.0
# Name: t+1, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, median_absolute_error, mean_squared_error  
print("The Mean Square Error: %.2f degrees celsius" % mean_squared_error (y_eval, final_pred))
print("The Root  Mean Square Error: %.2f degrees celsius" % np.sqrt(mean_squared_error (y_eval, final_pred)))
# Out:
# The Mean Square Error: 1.42 degrees celsius
# The Root  Mean Square Error: 1.19 degrees celsius

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(18,6))
plt.plot(y_eval, color = 'red')
plt.plot(final_pred, color = 'blue' )
